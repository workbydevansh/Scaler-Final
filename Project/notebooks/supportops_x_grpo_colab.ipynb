# %% [markdown]
# # SupportOps-X GRPO Training
#
# Use this notebook in Colab or another GPU runtime with your hackathon credits. Replace the repo URL with your Hugging Face Space or GitHub repo after upload.

# %%
# !pip install -q "openenv-core[core]>=0.2.3" "trl>=0.25" "datasets>=2.20" "transformers>=4.51" "accelerate>=1.0" unsloth matplotlib

# %% [markdown]
# Install your environment package. If you upload this repo to a Hugging Face Space, use the Space git URL.

# %%
# Example after upload:
# !pip install -q "openenv-supportops-x-env @ git+https://huggingface.co/spaces/<user>/supportops-x"
# For a local Colab upload, mount Drive or clone your repo, then:
# %cd /content/supportops-x
# !pip install -q -e .

# %%
# !python scripts/evaluate_policies.py

# %%
# !python training/train_grpo.py --model Qwen/Qwen3-0.6B --repeats 16 --max-steps 80 --output-dir outputs/supportops-x-grpo

# %% [markdown]
# After training, export the model/adapters, run evaluation again with the trained policy wrapper, and save reward/loss plots into `results/` for the README.
